# %% [markdown]
# # Supervised Deep Learning for Content-Aware Image Retargeting with Fourier Convolutions
#
# [Github](https://github.com/givkashi/CAIR)
# [Article](https://link.springer.com/article/10.1007/s11042-024-18876-8)
# [arXiv](https://arxiv.org/abs/2306.07383)

# %%
# !git clone https://github.com/givkashi/CAIR.git
# Out:
# Cloning into 'CAIR'...
# remote: Enumerating objects: 358, done.
# remote: Counting objects: 100% (358/358), done.
# remote: Compressing objects: 100% (321/321), done.
# remote: Total 358 (delta 34), reused 272 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (358/358), 5.07 MiB | 17.26 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# !git clone https://huggingface.co/givkashi/Image-Retargeting
# Out:
# Cloning into 'Image-Retargeting'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 10 (delta 0), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (10/10), 3.43 KiB | 1.14 MiB/s, done.

# %%
# !mv Image-Retargeting/checkpoint ./CAIR

# %%
# %cd CAIR
# Out:
# /content/CAIR

# %%
# !pip install -q albumentations==0.5.2
# !pip install -q hydra-core==1.1.0
# !pip install -q pytorch-lightning==1.2.9
# !pip install -q tabulate
# !pip install -q kornia==0.5.0
# !pip install -q webdataset
# !pip install -q packaging
# !pip install -q wldhx.yadisk-direct
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.6/144.6 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.9/841.9 kB 45.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.9/176.9 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.5/271.5 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 6.9 MB/s eta 0:00:00

# %% [markdown]
# # Inference

# %%
# !PYTHONPATH=. TORCH_HOME=$(pwd) python3 bin/predict.py
# Out:
# 2024-09-20 18:43:52.489026: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-20 18:43:52.510948: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-20 18:43:52.517303: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-20 18:43:52.532625: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
